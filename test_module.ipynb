# %% [markdown]
# # __init__

# %%
import src.keylogging_analysis as ka

kldf = ka.KeyLoggingDataFrame()
#kldf.load_data_from_path("./data/events_anonymized.csv", "./data/messages_anonymized.csv", "lh")
kldf.load_data_from_path("./data/keys.csv", "./data/messages.csv", "ll")

# %%
print(kldf)
# Out:
#         key_id message_id                   content                key_time  \
# 0            1          1                         H 2024-06-08 09:19:07.999
# 1            2          1                        He 2024-06-08 09:19:08.122
# 2            3          1                       Hel 2024-06-08 09:19:08.232
# 3            4          1                      Hell 2024-06-08 09:19:08.377
# 4            5          1                     Hello 2024-06-08 09:19:08.522
# ...        ...        ...                       ...                     ...
# 135435  135436       1530    tu peux mieux écrire ç 2025-08-04 08:27:42.168
# 135436  135437       1530   tu peux mieux écrire ça 2025-08-04 08:27:42.527
# 135437  135438       1530  tu peux mieux écrire ça? 2025-08-04 08:27:42.748
# 135438  135439       1531                       NaN 2025-08-04 08:31:54.390
# 135439  135440       1531                         f 2025-08-04 08:31:54.510
#
# ...
