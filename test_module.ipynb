# %% [markdown]
# # __init__
#
# test __init__ and load_data_from_path

# %%
import src.keylogging_analysis as ka

ll_kldf = ka.KeyLoggingDataFrame()
ll_kldf.load_data_from_path("./data/keys.csv", "./data/messages.csv", "ll")
ll_kldf.to_csv("ll_default.csv")

lh_kldf = ka.KeyLoggingDataFrame()
lh_kldf.load_data_from_path("./data/events_anonymized.csv", "./data/messages_anonymized.csv", "lh")
lh_kldf.to_csv("lh_default.csv")
# Out:
# c:\Users\kobet\keylogging_analysis\src\keylogging_analysis.py:108: UserWarning: There are 30368 keys without a corresponding message.
#   warnings.warn(f"There are {num_orphaned} keys without a corresponding message.")

# %% [markdown]
# # load_default_data

# %%
import src.keylogging_analysis as ka

default_lh = ka.KeyLoggingDataFrame()
default_lh.load_default_data("lh")
print(default_lh.head())

default_ll = ka.KeyLoggingDataFrame()
default_ll.load_default_data("ll")
print(default_ll.head())
# Out:
#    Unnamed: 0  key_id content event_for_message_type                key_time  \
# 0           0   35648   3,067                      5 2018-09-21 07:13:54.270
# 1           1   35649     NaN                      4 2018-09-21 07:14:07.751
# 2           2   35650   3,067                      5 2018-09-21 07:14:08.134
# 3           3   35651       B                      0 2018-09-21 07:14:16.829
# 4           4   35652      BO                      0 2018-09-21 07:14:17.254
#
#    message_id user_status message_content message_created_at  session_id  ...  \
# 0       11701           H         boujour                NaT         399  ...
# 1       11701           H         boujour                NaT         399  ...
# 2       11701           H         boujour                NaT         399  ...
# 3       11701           H         boujour                NaT         399  ...
# 4       11701           H         boujour                NaT         399  ...
#
#    creationDate_conversation  targetLang  tutorLang hasTasks CREATOR_ID  \
# 0    2018-09-21 07:13:53.609           1          0     True       1251
# 1    2018-09-21 07:13:53.609           1          0     True       1251
# 2    2018-09-21 07:13:53.609           1          0     True       1251
# 3    2018-09-21 07:13:53.609           1          0     True       1251
# 4    2018-09-21 07:13:53.609           1          0     True       1251
#
#    SCENARIO_ID  preCreated  simulated  archivedForProcessing  username
# 0            3       False      False                  False   user001
# 1            3       False      False                  False   user001
# 2            3       False      False                  False   user001
# 3            3       False      False                  False   user001
# 4            3       False      False                  False   user001
#
# [5 rows x 24 columns]
#    Unnamed: 0  key_id  message_id content                key_time  \
# 0           0       1           1       H 2024-06-08 09:19:07.999
# 1           1       2           1      He 2024-06-08 09:19:08.122
# 2           2       3           1     Hel 2024-06-08 09:19:08.232
# 3           3       4           1    Hell 2024-06-08 09:19:08.377
# 4           4       5           1   Hello 2024-06-08 09:19:08.522
#
#                         message_uid message_content  user_id  session_id  \
# 0  OrovKJP0X4nJgcs22N6cxfLSwYVFGbWu           Hello        1           1
# 1  OrovKJP0X4nJgcs22N6cxfLSwYVFGbWu           Hello        1           1
# 2  OrovKJP0X4nJgcs22N6cxfLSwYVFGbWu           Hello        1           1
# 3  OrovKJP0X4nJgcs22N6cxfLSwYVFGbWu           Hello        1           1
# 4  OrovKJP0X4nJgcs22N6cxfLSwYVFGbWu           Hello        1           1
#
#   reply_to_message_id         message_created_at
# 0                 NaN 2024-06-08 11:19:08.554499
# 1                 NaN 2024-06-08 11:19:08.554499
# 2                 NaN 2024-06-08 11:19:08.554499
# 3                 NaN 2024-06-08 11:19:08.554499
# 4                 NaN 2024-06-08 11:19:08.554499
